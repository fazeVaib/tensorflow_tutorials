# %% [markdown]
# # Explore overfitting and underfitting

# %%
import tensorflow as tf
import numpy as np
from tensorflow import keras
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# Rather than using an embedding as in the previous notebook, here we will multi-hot encode the sentences. This model will quickly overfit to the training set. It will be used to demonstrate when overfitting occurs, and how to fight it.
#
# Multi-hot-encoding our lists means turning them into vectors of 0s and 1s. Concretely, this would mean for instance turning the sequence [3, 5] into a 10,000-dimensional vector that would be all- zeros except for indices 3 and 5, which would be ones.

# %%
num_words = 10000
(train_data, train_label), (test_data, test_label) = keras.datasets.imdb.load_data(num_words=num_words)
print(train_data[0])

def multi_hot_seq(sequences, dimension):
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0
    return results

train_data = multi_hot_seq(train_data, dimension=num_words)
test_data = multi_hot_seq(test_data, dimension=num_words)
# Out:
# [1, 14, 22, 16, 43, 530, 973, 1622, 1385, 65, 458, 4468, 66, 3941, 4, 173, 36, 256, 5, 25, 100, 43, 838, 112, 50, 670, 2, 9, 35, 480, 284, 5, 150, 4, 172, 112, 167, 2, 336, 385, 39, 4, 172, 4536, 1111, 17, 546, 38, 13, 447, 4, 192, 50, 16, 6, 147, 2025, 19, 14, 22, 4, 1920, 4613, 469, 4, 22, 71, 87, 12, 16, 43, 530, 38, 76, 15, 13, 1247, 4, 22, 17, 515, 17, 12, 16, 626, 18, 2, 5, 62, 386, 12, 8, 316, 8, 106, 5, 4, 2223, 5244, 16, 480, 66, 3785, 33, 4, 130, 12, 16, 38, 619, 5, 25, 124, 51, 36, 135, 48, 25, 1415, 33, 6, 22, 12, 215, 28, 77, 52, 5, 14, 407, 16, 82, 2, 8, 4, 107, 117, 5952, 15, 256, 4, 2, 7, 3766, 5, 723, 36, 71, 43, 530, 476, 26, 400, 317, 46, 7, 4, 2, 1029, 13, 104, 88, 4, 381, 15, 297, 98, 32, 2071, 56, 26, 141, 6, 194, 7486, 18, 4, 226, 22, 21, 134, 476, 26, 480, 5, 144, 30, 5535, 18, 51, 36, 28, 224, 92, 25, 104, 4, 226, 65, 16, 38, 1334, 88, 12, 16, 283, 5, 16, 4472, 113, 103, 32, 15, 16, 5345, 19, 178, 32]

# %%
train_data[0]
# Out:
# array([ 0.,  1.,  1., ...,  0.,  0.,  0.])

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(10000,)),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

baseline_model.compile(optimizer='adam', loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 16)                160016
# _________________________________________________________________
# dense_4 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 160,305
# Trainable params: 160,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data, train_label, epochs=20,
                                     batch_size=512, validation_data=(test_data, test_label), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 14s - loss: 0.4784 - acc: 0.8072 - binary_crossentropy: 0.4784 - val_loss: 0.3331 - val_acc: 0.8749 - val_binary_crossentropy: 0.3331
# Epoch 2/20
#  - 3s - loss: 0.2457 - acc: 0.9123 - binary_crossentropy: 0.2457 - val_loss: 0.2848 - val_acc: 0.8869 - val_binary_crossentropy: 0.2848
# Epoch 3/20
#  - 2s - loss: 0.1800 - acc: 0.9370 - binary_crossentropy: 0.1800 - val_loss: 0.2910 - val_acc: 0.8842 - val_binary_crossentropy: 0.2910
# Epoch 4/20
#  - 2s - loss: 0.1428 - acc: 0.9518 - binary_crossentropy: 0.1428 - val_loss: 0.3176 - val_acc: 0.8779 - val_binary_crossentropy: 0.3176
# Epoch 5/20
#  - 2s - loss: 0.1163 - acc: 0.9618 - binary_crossentropy: 0.1163 - val_loss: 0.3446 - val_acc: 0.8742 - val_binary_crossentropy: 0.3446
# Epoch 6/20
#  - 3s - loss: 0.0915 - acc: 0.9727 - binary_crossentropy: 0.0915 - val_loss: 0.3803 - val_acc: 0.8694 - val_binary_crossentropy: 0.3803
# Epoch 7/20
#  - 2s - loss: 0.0697 - acc: 0.9820 - binary_crossentropy: 0.0697 - val_loss: 0.4349 - val_acc: 0.8607 - val_binary_crossentropy: 0.4349
# Epoch 8/20
#  - 2s - loss: 0.0525 - acc: 0.9879 - binary_crossentropy: 0.0525 - val_loss: 0.4591 - val_acc: 0.8641 - val_binary_crossentropy: 0.4591
# Epoch 9/20
#  - 2s - loss: 0.0378 - acc: 0.9930 - binary_crossentropy: 0.0378 - val_loss: 0.4995 - val_acc: 0.8615 - val_binary_crossentropy: 0.4995
# Epoch 10/20
#  - 2s - loss: 0.0263 - acc: 0.9962 - binary_crossentropy: 0.0263 - val_loss: 0.5487 - val_acc: 0.8578 - val_binary_crossentropy: 0.5487
# Epoch 11/20
#  - 3s - loss: 0.0180 - acc: 0.9983 - binary_crossentropy: 0.0180 - val_loss: 0.5924 - val_acc: 0.8593 - val_binary_crossentropy: 0.5924
# Epoch 12/20
#  - 3s - loss: 0.0123 - acc: 0.9992 - binary_crossentropy: 0.0123 - val_loss: 0.6325 - val_acc: 0.8576 - val_binary_crossentropy: 0.6325
# Epoch 13/20
#  - 2s - loss: 0.0087 - acc: 0.9996 - binary_crossentropy: 0.0087 - val_loss: 0.6695 - val_acc: 0.8578 - val_binary_crossentropy: 0.6695
# Epoch 14/20
#  - 2s - loss: 0.0063 - acc: 0.9998 - binary_crossentropy: 0.0063 - val_loss: 0.7010 - val_acc: 0.8564 - val_binary_crossentropy: 0.7010
# Epoch 15/20
#  - 2s - loss: 0.0047 - acc: 0.9999 - binary_crossentropy: 0.0047 - val_loss: 0.7355 - val_acc: 0.8577 - val_binary_crossentropy: 0.7355
# Epoch 16/20
#  - 2s - loss: 0.0035 - acc: 0.9999 - binary_crossentropy: 0.0035 - val_loss: 0.7730 - val_acc: 0.8571 - val_binary_crossentropy: 0.7730
# Epoch 17/20
#  - 2s - loss: 0.0025 - acc: 1.0000 - binary_crossentropy: 0.0025 - val_loss: 0.8112 - val_acc: 0.8572 - val_binary_crossentropy: 0.8112
# Epoch 18/20
#  - 2s - loss: 0.0019 - acc: 1.0000 - binary_crossentropy: 0.0019 - val_loss: 0.8462 - val_acc: 0.8566 - val_binary_crossentropy: 0.8462
# Epoch 19/20
#  - 2s - loss: 0.0014 - acc: 1.0000 - binary_crossentropy: 0.0014 - val_loss: 0.8765 - val_acc: 0.8563 - val_binary_crossentropy: 0.8765
# Epoch 20/20
#  - 2s - loss: 0.0011 - acc: 1.0000 - binary_crossentropy: 0.0011 - val_loss: 0.9057 - val_acc: 0.8561 - val_binary_crossentropy: 0.9057

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation=tf.nn.relu, input_shape=(10000,)),
    keras.layers.Dense(4, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

smaller_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy','binary_crossentropy'])

smaller_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 4)                 40004
# _________________________________________________________________
# dense_7 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 40,029
# Trainable params: 40,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data, train_label, epochs=20,
                                     batch_size=512, validation_data=(test_data, test_label), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.5590 - acc: 0.7689 - binary_crossentropy: 0.5590 - val_loss: 0.4317 - val_acc: 0.8580 - val_binary_crossentropy: 0.4317
# Epoch 2/20
#  - 2s - loss: 0.3335 - acc: 0.8931 - binary_crossentropy: 0.3335 - val_loss: 0.3253 - val_acc: 0.8802 - val_binary_crossentropy: 0.3253
# Epoch 3/20
#  - 2s - loss: 0.2483 - acc: 0.9185 - binary_crossentropy: 0.2483 - val_loss: 0.2923 - val_acc: 0.8861 - val_binary_crossentropy: 0.2923
# Epoch 4/20
#  - 2s - loss: 0.2020 - acc: 0.9333 - binary_crossentropy: 0.2020 - val_loss: 0.2839 - val_acc: 0.8873 - val_binary_crossentropy: 0.2839
# Epoch 5/20
#  - 3s - loss: 0.1694 - acc: 0.9452 - binary_crossentropy: 0.1694 - val_loss: 0.2871 - val_acc: 0.8846 - val_binary_crossentropy: 0.2871
# Epoch 6/20
#  - 2s - loss: 0.1448 - acc: 0.9548 - binary_crossentropy: 0.1448 - val_loss: 0.2941 - val_acc: 0.8817 - val_binary_crossentropy: 0.2941
# Epoch 7/20
#  - 2s - loss: 0.1252 - acc: 0.9632 - binary_crossentropy: 0.1252 - val_loss: 0.3065 - val_acc: 0.8788 - val_binary_crossentropy: 0.3065
# Epoch 8/20
#  - 2s - loss: 0.1095 - acc: 0.9689 - binary_crossentropy: 0.1095 - val_loss: 0.3217 - val_acc: 0.8780 - val_binary_crossentropy: 0.3217
# Epoch 9/20
#  - 2s - loss: 0.0963 - acc: 0.9738 - binary_crossentropy: 0.0963 - val_loss: 0.3361 - val_acc: 0.8760 - val_binary_crossentropy: 0.3361
# Epoch 10/20
#  - 2s - loss: 0.0843 - acc: 0.9780 - binary_crossentropy: 0.0843 - val_loss: 0.3542 - val_acc: 0.8730 - val_binary_crossentropy: 0.3542
# Epoch 11/20
#  - 2s - loss: 0.0742 - acc: 0.9816 - binary_crossentropy: 0.0742 - val_loss: 0.3765 - val_acc: 0.8694 - val_binary_crossentropy: 0.3765
# Epoch 12/20
#  - 2s - loss: 0.0648 - acc: 0.9860 - binary_crossentropy: 0.0648 - val_loss: 0.3907 - val_acc: 0.8678 - val_binary_crossentropy: 0.3907
# Epoch 13/20
#  - 2s - loss: 0.0568 - acc: 0.9886 - binary_crossentropy: 0.0568 - val_loss: 0.4136 - val_acc: 0.8659 - val_binary_crossentropy: 0.4136
# Epoch 14/20
#  - 2s - loss: 0.0495 - acc: 0.9909 - binary_crossentropy: 0.0495 - val_loss: 0.4341 - val_acc: 0.8647 - val_binary_crossentropy: 0.4341
# Epoch 15/20
#  - 2s - loss: 0.0433 - acc: 0.9929 - binary_crossentropy: 0.0433 - val_loss: 0.4567 - val_acc: 0.8632 - val_binary_crossentropy: 0.4567
# Epoch 16/20
#  - 2s - loss: 0.0380 - acc: 0.9947 - binary_crossentropy: 0.0380 - val_loss: 0.4736 - val_acc: 0.8618 - val_binary_crossentropy: 0.4736
# Epoch 17/20
#  - 2s - loss: 0.0332 - acc: 0.9953 - binary_crossentropy: 0.0332 - val_loss: 0.4955 - val_acc: 0.8603 - val_binary_crossentropy: 0.4955
# Epoch 18/20
#  - 2s - loss: 0.0289 - acc: 0.9966 - binary_crossentropy: 0.0289 - val_loss: 0.5235 - val_acc: 0.8588 - val_binary_crossentropy: 0.5235
# Epoch 19/20
#  - 2s - loss: 0.0250 - acc: 0.9974 - binary_crossentropy: 0.0250 - val_loss: 0.5380 - val_acc: 0.8586 - val_binary_crossentropy: 0.5380
# Epoch 20/20
#  - 2s - loss: 0.0221 - acc: 0.9978 - binary_crossentropy: 0.0221 - val_loss: 0.5602 - val_acc: 0.8582 - val_binary_crossentropy: 0.5602

# %%
bigger_model = keras.Sequential([
    keras.layers.Dense(512, activation=tf.nn.relu, input_shape=(10000,)),
    keras.layers.Dense(512, activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

bigger_model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_9 (Dense)              (None, 512)               5120512
# _________________________________________________________________
# dense_10 (Dense)             (None, 512)               262656
# _________________________________________________________________
# dense_11 (Dense)             (None, 1)                 513
# =================================================================
# Total params: 5,383,681
# Trainable params: 5,383,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_label, epochs=20,
                                     batch_size=512, validation_data=(test_data, test_label), verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 12s - loss: 0.3451 - acc: 0.8547 - binary_crossentropy: 0.3451 - val_loss: 0.2950 - val_acc: 0.8802 - val_binary_crossentropy: 0.2950
# Epoch 2/20
#  - 11s - loss: 0.1357 - acc: 0.9504 - binary_crossentropy: 0.1357 - val_loss: 0.3573 - val_acc: 0.8626 - val_binary_crossentropy: 0.3573
# Epoch 3/20
#  - 11s - loss: 0.0412 - acc: 0.9885 - binary_crossentropy: 0.0412 - val_loss: 0.4429 - val_acc: 0.8669 - val_binary_crossentropy: 0.4429
# Epoch 4/20
#  - 11s - loss: 0.0061 - acc: 0.9995 - binary_crossentropy: 0.0061 - val_loss: 0.5931 - val_acc: 0.8710 - val_binary_crossentropy: 0.5931
# Epoch 5/20
#  - 11s - loss: 6.2351e-04 - acc: 1.0000 - binary_crossentropy: 6.2351e-04 - val_loss: 0.6708 - val_acc: 0.8715 - val_binary_crossentropy: 0.6708
# Epoch 6/20
#  - 11s - loss: 2.1329e-04 - acc: 1.0000 - binary_crossentropy: 2.1329e-04 - val_loss: 0.7091 - val_acc: 0.8715 - val_binary_crossentropy: 0.7091
# Epoch 7/20
#  - 11s - loss: 1.3183e-04 - acc: 1.0000 - binary_crossentropy: 1.3183e-04 - val_loss: 0.7334 - val_acc: 0.8721 - val_binary_crossentropy: 0.7334
# Epoch 8/20
#  - 11s - loss: 9.4932e-05 - acc: 1.0000 - binary_crossentropy: 9.4932e-05 - val_loss: 0.7517 - val_acc: 0.8724 - val_binary_crossentropy: 0.7517
# Epoch 9/20
#  - 11s - loss: 7.2698e-05 - acc: 1.0000 - binary_crossentropy: 7.2698e-05 - val_loss: 0.7669 - val_acc: 0.8729 - val_binary_crossentropy: 0.7669
# Epoch 10/20
#  - 11s - loss: 5.7730e-05 - acc: 1.0000 - binary_crossentropy: 5.7730e-05 - val_loss: 0.7794 - val_acc: 0.8731 - val_binary_crossentropy: 0.7794
# Epoch 11/20
#  - 11s - loss: 4.7121e-05 - acc: 1.0000 - binary_crossentropy: 4.7121e-05 - val_loss: 0.7912 - val_acc: 0.8729 - val_binary_crossentropy: 0.7912
# Epoch 12/20
#  - 11s - loss: 3.9122e-05 - acc: 1.0000 - binary_crossentropy: 3.9122e-05 - val_loss: 0.8013 - val_acc: 0.8726 - val_binary_crossentropy: 0.8013
# Epoch 13/20
#  - 11s - loss: 3.2996e-05 - acc: 1.0000 - binary_crossentropy: 3.2996e-05 - val_loss: 0.8103 - val_acc: 0.8730 - val_binary_crossentropy: 0.8103
# Epoch 14/20
#  - 11s - loss: 2.8186e-05 - acc: 1.0000 - binary_crossentropy: 2.8186e-05 - val_loss: 0.8189 - val_acc: 0.8728 - val_binary_crossentropy: 0.8189
# Epoch 15/20
#  - 11s - loss: 2.4316e-05 - acc: 1.0000 - binary_crossentropy: 2.4316e-05 - val_loss: 0.8269 - val_acc: 0.8728 - val_binary_crossentropy: 0.8269
# Epoch 16/20
#  - 11s - loss: 2.1180e-05 - acc: 1.0000 - binary_crossentropy: 2.1180e-05 - val_loss: 0.8336 - val_acc: 0.8733 - val_binary_crossentropy: 0.8336
# Epoch 17/20
#  - 11s - loss: 1.8585e-05 - acc: 1.0000 - binary_crossentropy: 1.8585e-05 - val_loss: 0.8415 - val_acc: 0.8723 - val_binary_crossentropy: 0.8415
# Epoch 18/20
#  - 11s - loss: 1.6436e-05 - acc: 1.0000 - binary_crossentropy: 1.6436e-05 - val_loss: 0.8473 - val_acc: 0.8726 - val_binary_crossentropy: 0.8473
# Epoch 19/20
#  - 11s - loss: 1.4589e-05 - acc: 1.0000 - binary_crossentropy: 1.4589e-05 - val_loss: 0.8534 - val_acc: 0.8726 - val_binary_crossentropy: 0.8534
# Epoch 20/20
#  - 11s - loss: 1.3042e-05 - acc: 1.0000 - binary_crossentropy: 1.3042e-05 - val_loss: 0.8597 - val_acc: 0.8724 - val_binary_crossentropy: 0.8597

# %%
def plot_history(histories, key='binary_crossentropy'):
    plt.figure(figsize=(16,10))
    
    for name, history in histories:
        val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
        plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

    plt.xlabel('Epochs')
    plt.ylabel(key.replace('_',' ').title())
    plt.legend()

    plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %% [markdown]
# A "simple model" in this context is a model where the distribution of parameter values has less entropy (or a model with fewer parameters altogether, as we saw in the section above). Thus a common way to mitigate overfitting is to put constraints on the complexity of a network by forcing its weights only to take small values, which makes the distribution of weight values more "regular". This is called "weight regularization", and it is done by adding to the loss function of the network a cost associated with having large weights. This cost comes in two flavors:
#
# 1. L1 regularization, where the cost added is proportional to the absolute value of the weights coefficients (i.e. to what is called the "L1 norm" of the weights).
#
# 2. L2 regularization, where the cost added is proportional to the square of the value of the weights coefficients (i.e. to what is called the "L2 norm" of the weights). L2 regularization is also called weight decay in the context of neural networks. Don't let the different name confuse you: weight decay is mathematically the exact same as L2 regularization.
#
# In tf.keras, weight regularization is added by passing weight regularizer instances to layers as keyword arguments. Let's add L2 weight regularization now.

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu, input_shape=(10000,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation=tf.nn.relu),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_label,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_label),
                                verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.5437 - acc: 0.8129 - binary_crossentropy: 0.5041 - val_loss: 0.4167 - val_acc: 0.8686 - val_binary_crossentropy: 0.3753
# Epoch 2/20
#  - 3s - loss: 0.3375 - acc: 0.9022 - binary_crossentropy: 0.2910 - val_loss: 0.3493 - val_acc: 0.8841 - val_binary_crossentropy: 0.2990
# Epoch 3/20
#  - 3s - loss: 0.2823 - acc: 0.9195 - binary_crossentropy: 0.2295 - val_loss: 0.3391 - val_acc: 0.8858 - val_binary_crossentropy: 0.2847
# Epoch 4/20
#  - 2s - loss: 0.2558 - acc: 0.9316 - binary_crossentropy: 0.1998 - val_loss: 0.3408 - val_acc: 0.8853 - val_binary_crossentropy: 0.2841
# Epoch 5/20
#  - 2s - loss: 0.2405 - acc: 0.9373 - binary_crossentropy: 0.1825 - val_loss: 0.3500 - val_acc: 0.8818 - val_binary_crossentropy: 0.2915
# Epoch 6/20
#  - 2s - loss: 0.2274 - acc: 0.9436 - binary_crossentropy: 0.1681 - val_loss: 0.3580 - val_acc: 0.8794 - val_binary_crossentropy: 0.2985
# Epoch 7/20
#  - 2s - loss: 0.2183 - acc: 0.9454 - binary_crossentropy: 0.1579 - val_loss: 0.3720 - val_acc: 0.8765 - val_binary_crossentropy: 0.3110
# Epoch 8/20
#  - 3s - loss: 0.2079 - acc: 0.9501 - binary_crossentropy: 0.1463 - val_loss: 0.3783 - val_acc: 0.8756 - val_binary_crossentropy: 0.3167
# Epoch 9/20
#  - 2s - loss: 0.2012 - acc: 0.9530 - binary_crossentropy: 0.1392 - val_loss: 0.3928 - val_acc: 0.8731 - val_binary_crossentropy: 0.3304
# Epoch 10/20
#  - 3s - loss: 0.1983 - acc: 0.9530 - binary_crossentropy: 0.1352 - val_loss: 0.4112 - val_acc: 0.8696 - val_binary_crossentropy: 0.3478
# Epoch 11/20
#  - 3s - loss: 0.1928 - acc: 0.9556 - binary_crossentropy: 0.1289 - val_loss: 0.4143 - val_acc: 0.8697 - val_binary_crossentropy: 0.3500
# Epoch 12/20
#  - 4s - loss: 0.1880 - acc: 0.9570 - binary_crossentropy: 0.1236 - val_loss: 0.4317 - val_acc: 0.8666 - val_binary_crossentropy: 0.3672
# Epoch 13/20
#  - 3s - loss: 0.1871 - acc: 0.9572 - binary_crossentropy: 0.1216 - val_loss: 0.4341 - val_acc: 0.8667 - val_binary_crossentropy: 0.3685
# Epoch 14/20
#  - 3s - loss: 0.1776 - acc: 0.9620 - binary_crossentropy: 0.1121 - val_loss: 0.4425 - val_acc: 0.8637 - val_binary_crossentropy: 0.3775
# Epoch 15/20
#  - 4s - loss: 0.1725 - acc: 0.9636 - binary_crossentropy: 0.1074 - val_loss: 0.4542 - val_acc: 0.8639 - val_binary_crossentropy: 0.3889
# Epoch 16/20
#  - 3s - loss: 0.1698 - acc: 0.9652 - binary_crossentropy: 0.1043 - val_loss: 0.4666 - val_acc: 0.8611 - val_binary_crossentropy: 0.4010
# Epoch 17/20
#  - 4s - loss: 0.1682 - acc: 0.9653 - binary_crossentropy: 0.1024 - val_loss: 0.4726 - val_acc: 0.8610 - val_binary_crossentropy: 0.4064
# Epoch 18/20
#  - 3s - loss: 0.1655 - acc: 0.9658 - binary_crossentropy: 0.0991 - val_loss: 0.4952 - val_acc: 0.8584 - val_binary_crossentropy: 0.4286
# Epoch 19/20
#  - 3s - loss: 0.1639 - acc: 0.9656 - binary_crossentropy: 0.0970 - val_loss: 0.4962 - val_acc: 0.8601 - val_binary_crossentropy: 0.4290
# Epoch 20/20
#  - 3s - loss: 0.1606 - acc: 0.9683 - binary_crossentropy: 0.0931 - val_loss: 0.5076 - val_acc: 0.8569 - val_binary_crossentropy: 0.4401

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %% [markdown]
# Dropout is one of the most effective and most commonly used regularization techniques for neural networks, developed by Hinton and his students at the University of Toronto. Dropout, applied to a layer, consists of randomly "dropping out" (i.e. set to zero) a number of output features of the layer during training. Let's say a given layer would normally have returned a vector [0.2, 0.5, 1.3, 0.8, 1.1] for a given input sample during training; after applying dropout, this vector will have a few zero entries distributed at random, e.g. [0, 0.5, 1.3, 0, 1.1]. The "dropout rate" is the fraction of the features that are being zeroed-out; it is usually set between 0.2 and 0.5. At test time, no units are dropped out, and instead the layer's output values are scaled down by a factor equal to the dropout rate, so as to balance for the fact that more units are active than at training time.
#
# In tf.keras you can introduce dropout in a network via the Dropout layer, which gets applied to the output of layer right before.
#
# Let's add two Dropout layers in our IMDB network to see how well they do at reducing overfitting:

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation=tf.nn.relu, input_shape=(10000,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation=tf.nn.relu),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation=tf.nn.sigmoid)
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_label,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_label),
                                  verbose=2)
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/20
#  - 3s - loss: 0.6358 - acc: 0.6210 - binary_crossentropy: 0.6358 - val_loss: 0.5274 - val_acc: 0.8461 - val_binary_crossentropy: 0.5274
# Epoch 2/20
#  - 3s - loss: 0.4879 - acc: 0.7733 - binary_crossentropy: 0.4879 - val_loss: 0.3723 - val_acc: 0.8770 - val_binary_crossentropy: 0.3723
# Epoch 3/20
#  - 3s - loss: 0.3855 - acc: 0.8449 - binary_crossentropy: 0.3855 - val_loss: 0.3087 - val_acc: 0.8857 - val_binary_crossentropy: 0.3087
# Epoch 4/20
#  - 2s - loss: 0.3189 - acc: 0.8810 - binary_crossentropy: 0.3189 - val_loss: 0.2802 - val_acc: 0.8885 - val_binary_crossentropy: 0.2802
# Epoch 5/20
#  - 2s - loss: 0.2726 - acc: 0.8972 - binary_crossentropy: 0.2726 - val_loss: 0.2769 - val_acc: 0.8882 - val_binary_crossentropy: 0.2769
# Epoch 6/20
#  - 2s - loss: 0.2455 - acc: 0.9092 - binary_crossentropy: 0.2455 - val_loss: 0.2820 - val_acc: 0.8867 - val_binary_crossentropy: 0.2820
# Epoch 7/20
#  - 2s - loss: 0.2165 - acc: 0.9223 - binary_crossentropy: 0.2165 - val_loss: 0.2952 - val_acc: 0.8858 - val_binary_crossentropy: 0.2952
# Epoch 8/20
#  - 2s - loss: 0.1965 - acc: 0.9263 - binary_crossentropy: 0.1965 - val_loss: 0.3002 - val_acc: 0.8840 - val_binary_crossentropy: 0.3002
# Epoch 9/20
#  - 2s - loss: 0.1755 - acc: 0.9350 - binary_crossentropy: 0.1755 - val_loss: 0.3194 - val_acc: 0.8832 - val_binary_crossentropy: 0.3194
# Epoch 10/20
#  - 3s - loss: 0.1640 - acc: 0.9366 - binary_crossentropy: 0.1640 - val_loss: 0.3375 - val_acc: 0.8832 - val_binary_crossentropy: 0.3375
# Epoch 11/20
#  - 3s - loss: 0.1451 - acc: 0.9432 - binary_crossentropy: 0.1451 - val_loss: 0.3599 - val_acc: 0.8820 - val_binary_crossentropy: 0.3599
# Epoch 12/20
#  - 2s - loss: 0.1405 - acc: 0.9455 - binary_crossentropy: 0.1405 - val_loss: 0.3815 - val_acc: 0.8813 - val_binary_crossentropy: 0.3815
# Epoch 13/20
#  - 3s - loss: 0.1345 - acc: 0.9450 - binary_crossentropy: 0.1345 - val_loss: 0.3912 - val_acc: 0.8800 - val_binary_crossentropy: 0.3912
# Epoch 14/20
#  - 2s - loss: 0.1196 - acc: 0.9505 - binary_crossentropy: 0.1196 - val_loss: 0.4138 - val_acc: 0.8796 - val_binary_crossentropy: 0.4138
# Epoch 15/20
#  - 2s - loss: 0.1150 - acc: 0.9508 - binary_crossentropy: 0.1150 - val_loss: 0.4175 - val_acc: 0.8786 - val_binary_crossentropy: 0.4175
# Epoch 16/20
#  - 2s - loss: 0.1091 - acc: 0.9523 - binary_crossentropy: 0.1091 - val_loss: 0.4364 - val_acc: 0.8790 - val_binary_crossentropy: 0.4364
# Epoch 17/20
#  - 2s - loss: 0.1013 - acc: 0.9550 - binary_crossentropy: 0.1013 - val_loss: 0.4389 - val_acc: 0.8766 - val_binary_crossentropy: 0.4389
# Epoch 18/20
#  - 2s - loss: 0.0971 - acc: 0.9558 - binary_crossentropy: 0.0971 - val_loss: 0.4930 - val_acc: 0.8780 - val_binary_crossentropy: 0.4930
# Epoch 19/20
#  - 2s - loss: 0.0913 - acc: 0.9572 - binary_crossentropy: 0.0913 - val_loss: 0.4918 - val_acc: 0.8760 - val_binary_crossentropy: 0.4918
# Epoch 20/20
#  - 3s - loss: 0.0896 - acc: 0.9581 - binary_crossentropy: 0.0896 - val_loss: 0.5039 - val_acc: 0.8763 - val_binary_crossentropy: 0.5039

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])

# %% [markdown]
# Adding dropout is a clear improvement over the baseline model.
#
# To recap: here the most common ways to prevent overfitting in neural networks:
#
# - Get more training data.
# - Reduce the capacity of the network.
# - Add weight regularization.
# - Add dropout.
